# %% [markdown]
# ## Communicating my Analysis and insight

# %% [markdown]
# Looking at the chart, it gives the information of dog name who have a name_count above eight(8). it can  be clearly seen that most or the highest dog name rated was the dog name with "a".Maybe this particular dog has one of the best; picture quality, beautiful colour, or the tweet actuallly got sponosred, or is a dog of one of a very influencer personality in the world.
#
# Also, the chart shows a fair distribution across with the expection of the strange dog name"a" with a progression from left to right making the chart more skewed to the left. this means that, these set of dog names would be the ones we are mostly likely to come across than other names that are not on this list.
#
# Some clear reasons maybe aslo be that:
#
# (1) these names may be found or common to a parcticular geographical location where most people who participated in the dog rating tweeted from.
#
# (2) These dog names may seems to be very coomom in various dog naming sites online.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The dog stage may also seems to be an important factor when rating dog. looking straight into the chart puppper has the highest while the floofer has the least. this is a claer indication that most of the dogd been rated where of pupper stages.
#
# (1) The pupper shows more attribute than the rest
# (@) The owns of the floofer dog stage did not indicate their dog stage when tweeting.
#
# ![image.png](attachment:image.png)
